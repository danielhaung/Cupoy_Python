# %% [markdown]
# 反爬：登入授權模擬
# ==
# 了解「登入權限機制」的反爬蟲機制<br>
# 「登入權限機制」反爬蟲的因應策略
# 未授權前存取
# ==

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify = False)
soup = BeautifulSoup(res.text, 'lxml')
print(soup.text)
# Out:
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開
#
#
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');

# %% [markdown]
# 模仿授權機制
# ==
# 方法一：先送登入，再送請求
# --

# %%
rs = requests.session()
payload={
    'from':'/bbs/Gossiping/index.html',
    'yes': 'yes'
}
res = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
#
#
# [新聞] 美對台軍售 環時：共軍一定要飛到台灣上
#
#
# scum5566
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 scum5566 的文章
#
#
# 10/27
#
#
#
#
# 10
#
# [新聞] 抓到了！散播合歡山塞車舊圖　南投警查
#
#
# johnny9667
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 johnny9667 的文章
#
#
# 10/27
#
#
#
#
# 1
#
# Re: [新聞] 被控「右翼錯誤訊息」《大紀元》槓上《紐
#
#
# extemjin
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 extemjin 的文章
#
#
# 10/27
#
#
#
#
#
#
# Re: [問卦] 貝莉莓：我4天賺50萬 我需要去賣？
#
#
# YaoFun5566
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 YaoFun5566 的文章
#
#
# 10/27
#
#
#
#
#
#
# Re: [問卦] 側翼名嘴拼命帶川普風向為了啥
#
#
# Lailungsheng
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Lailungsheng 的文章
#
#
# 10/27
#
#
#
#
# 2
#
# Re: [新聞] 夜市妹狂吃600！男怨「約會沒AA制」 網轟
#
#
# WomanizerNo7
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 WomanizerNo7 的文章
#
#
# 10/27
#
#
#
#
# 2
#
# [問卦] 中國打過來，平民能逃去哪？
#
#
# Jerome18
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Jerome18 的文章
#
#
# 10/27
#
#
#
#
#
#
# Re: [新聞] 夜市妹狂吃600！男怨「約會沒AA制」 網轟
#
#
# traman
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 traman 的文章
#
#
# 10/27
#
#
#
#
#
#
# [問卦] 為什麼全中國要封殺蛋炒飯
#
#
# a9606093
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 a9606093 的文章
#
#
# 10/27
#
#
#
#
# 3
#
# [問卦] 有沒有選舉時被放生的美國州
#
#
# maybetodo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 maybetodo 的文章
#
#
# 10/27
#
#
#
#
#
#
# [問卦] 有沒有高鐵上爆乳妹的卦
#
#
# xxxluke
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 xxxluke 的文章
#
#
# 10/27
#
#
#
#
# 1
#
# [問卦] 辦公室只剩一個人該做些什麼？
#
#
# Ericz7000
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Ericz7000 的文章
#
#
# 10/27
#
#
#
#
#
#
# Re: [問卦]4%仔開始扯「鑑定人鑑定不公」了？
#
#
# keyoard
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 keyoard 的文章
#
#
# 10/27
#
#
#
#
#
#
# Re: [新聞] 夜市妹狂吃600！男怨「約會沒AA制」 網轟
#
#
# Warheart
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Warheart 的文章
#
#
# 10/27
#
#
#
#
#
#
# [新聞] 最新民調 最討厭的政治人物蘇貞昌拿下第
#
#
# sincsnow
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 sincsnow 的文章
#
#
# 10/27
#
#
#
#
#
# 1
#
# [公告] 八卦板板規(2020.10.11)
#
#
# seabox
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 seabox 的文章
#
#
# 10/11
# !
#
#
#
# 18
#
# [協尋] 10/20八德富榮街 行車紀錄器
#
#
# fs700527
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 fs700527 的文章
#
#
# 10/21
#
#
#
#
# 5
#
# [協尋] 10/25 15:31 78快速道路肇事車輛協尋
#
#
# lenvalentine
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 lenvalentine 的文章
#
#
# 10/25
#
#
#
#
#
#
# [公告]十月份置底閒聊區
#
#
# ubcs
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ubcs 的文章
#
#
# 10/07
# M
#
#
#
# 10
#
# [協尋] 行車記錄器 新北市大觀路三段與環漢路交
#
#
# ifyou
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ifyou 的文章
#
#
# 10/23
#
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');

# %% [markdown]
# 方法二：在請求中帶入 cookie
# ==

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False, cookies={'over18': '1'})
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
#
#
# [新聞] 美對台軍售 環時：共軍一定要飛到台灣上
#
#
# scum5566
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 scum5566 的文章
#
#
# 10/27
#
#
#
#
# 10
#
# [新聞] 抓到了！散播合歡山塞車舊圖　南投警查
#
#
# johnny9667
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 johnny9667 的文章
#
#
# 10/27
#
#
#
#
# 1
#
# Re: [新聞] 被控「右翼錯誤訊息」《大紀元》槓上《紐
#
#
# extemjin
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 extemjin 的文章
#
#
# 10/27
#
#
#
#
#
#
# Re: [問卦] 貝莉莓：我4天賺50萬 我需要去賣？
#
#
# YaoFun5566
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 YaoFun5566 的文章
#
#
# 10/27
#
#
#
#
#
#
# Re: [問卦] 側翼名嘴拼命帶川普風向為了啥
#
#
# Lailungsheng
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Lailungsheng 的文章
#
#
# 10/27
#
#
#
#
# 2
#
# Re: [新聞] 夜市妹狂吃600！男怨「約會沒AA制」 網轟
#
#
# WomanizerNo7
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 WomanizerNo7 的文章
#
#
# 10/27
#
#
#
#
# 2
#
# [問卦] 中國打過來，平民能逃去哪？
#
#
# Jerome18
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Jerome18 的文章
#
#
# 10/27
#
#
#
#
#
#
# Re: [新聞] 夜市妹狂吃600！男怨「約會沒AA制」 網轟
#
#
# traman
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 traman 的文章
#
#
# 10/27
#
#
#
#
#
#
# [問卦] 為什麼全中國要封殺蛋炒飯
#
#
# a9606093
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 a9606093 的文章
#
#
# 10/27
#
#
#
#
# 3
#
# [問卦] 有沒有選舉時被放生的美國州
#
#
# maybetodo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 maybetodo 的文章
#
#
# 10/27
#
#
#
#
#
#
# [問卦] 有沒有高鐵上爆乳妹的卦
#
#
# xxxluke
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 xxxluke 的文章
#
#
# 10/27
#
#
#
#
# 1
#
# [問卦] 辦公室只剩一個人該做些什麼？
#
#
# Ericz7000
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Ericz7000 的文章
#
#
# 10/27
#
#
#
#
#
#
# Re: [問卦]4%仔開始扯「鑑定人鑑定不公」了？
#
#
# keyoard
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 keyoard 的文章
#
#
# 10/27
#
#
#
#
#
#
# Re: [新聞] 夜市妹狂吃600！男怨「約會沒AA制」 網轟
#
#
# Warheart
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Warheart 的文章
#
#
# 10/27
#
#
#
#
#
#
# [新聞] 最新民調 最討厭的政治人物蘇貞昌拿下第
#
#
# sincsnow
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 sincsnow 的文章
#
#
# 10/27
#
#
#
#
#
# 1
#
# [公告] 八卦板板規(2020.10.11)
#
#
# seabox
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 seabox 的文章
#
#
# 10/11
# !
#
#
#
# 18
#
# [協尋] 10/20八德富榮街 行車紀錄器
#
#
# fs700527
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 fs700527 的文章
#
#
# 10/21
#
#
#
#
# 5
#
# [協尋] 10/25 15:31 78快速道路肇事車輛協尋
#
#
# lenvalentine
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 lenvalentine 的文章
#
#
# 10/25
#
#
#
#
#
#
# [公告]十月份置底閒聊區
#
#
# ubcs
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ubcs 的文章
#
#
# 10/07
# M
#
#
#
# 10
#
# [協尋] 行車記錄器 新北市大觀路三段與環漢路交
#
#
# ifyou
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ifyou 的文章
#
#
# 10/23
#
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
